# %%
# --- Notebook Cell 1: Imports and Merge Functions ---
import os
import pandas as pd

# %%
def load_and_merge_folder(folder_path, date_col="date"):
    csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]
    merged_df = None
    merged_columns = set()

    for filename in csv_files:
        df = pd.read_csv(os.path.join(folder_path, filename))
        df.columns = [col.lower().strip() for col in df.columns]

        if date_col not in df.columns:
            print(f"Skipping {filename} — no `{date_col}` column")
            continue

        df[date_col] = pd.to_datetime(df[date_col])
        new_cols = [col for col in df.columns if col == date_col or col not in merged_columns]

        if merged_df is None:
            merged_df = df
        else:
            merged_df = pd.merge(merged_df, df[new_cols], on=date_col, how="outer")

        merged_columns.update(new_cols)

    return merged_df

# %%
# --- Notebook Cell 2: Clean & Interpolate ---
def interpolate_and_clean(df, date_col="date"):
    df = df.sort_values(date_col)
    numeric_cols = df.select_dtypes(include="number").columns
    df[numeric_cols] = df[numeric_cols].interpolate(method="linear", limit_direction="both")
    df = df.dropna(axis=1, how="all")
    df = df.dropna(axis=0, how="any")
    return df

# %%
# --- Notebook Cell 3: Merge Helpers ---
def merge_on_date(df1, df2, date_col="date"):
    shared_cols = set(df1.columns).intersection(df2.columns) - {date_col}
    df2 = df2.drop(columns=shared_cols)
    return pd.merge(df1, df2, on=date_col, how="outer")

# %%
# --- Notebook Cell 4: Full Pipeline Execution ---
# Merge all FRED-style CSVs from folder
fred_df = load_and_merge_folder("fredstuff/")
fred_df = interpolate_and_clean(fred_df)

# %%
fred_df.head()
# Out:
#         date  layman__oil_price  layman__gas_price  layman__mortgage_rate  \
# 0 1997-01-01              27.65              1.316                   8.25
# 1 1997-02-01              27.65              1.316                   8.25
# 2 1997-03-01              27.65              1.316                   8.25
# 3 1997-04-01              27.65              1.316                   8.25
# 4 1997-05-01              27.65              1.316                   8.25
#
#    layman__housing_prices  layman__grocery_index  layman__retail_sales  \
# 0                   100.0                  166.3              268044.0
# 1                   100.0                  166.3              268044.0
# 2                   100.0                  166.3              268044.0
# 3                   100.0                  166.3              268044.0
# 4                   100.0                  166.3              268044.0
#
#    layman__electricity_cost_index  layman__used_car_prices  \
# 0                           117.3                    153.9
# 1                           117.3                    153.9
# 2                           117.3                    153.9
# 3                           117.3                    153.9
# 4                           117.3                    153.9
#
#    layman__minimum_wage_trend  ...  linchpin__nonfarm_payrolls  \
# 0                        5.15  ...                    131011.0
# 1                        5.15  ...                    131011.0
# 2                        5.15  ...                    131011.0
# 3                        5.15  ...                    131011.0
# 4                        5.15  ...                    131011.0
#
#    linchpin__real_gdp_growth  linchpin__s&p500_returns  \
# 0                  13878.147                 -0.020108
# 1                  13878.147                 -0.020108
# 2                  13878.147                 -0.020108
# 3                  13878.147                 -0.020108
# 4                  13878.147                 -0.020108
#
#    linchpin__ism_nonmanufacturing_index  linchpin__export_prices  \
# 0                              0.006353                -0.003048
# 1                              0.006353                -0.003048
# 2                              0.006353                -0.003048
# 3                              0.006353                -0.003048
# 4                              0.006353                -0.003048
#
#    google_trends_unemployment  tiktok_recession_hashtag_velocity  \
# 0                        10.0                                0.0
# 1                        10.0                                0.0
# 2                        10.0                                0.0
# 3                        10.0                                0.0
# 4                        10.0                                0.0
#
#    reddit_finance_sentiment  twitter_macro_fear_score  \
# 0                      54.0                      17.0
# 1                      54.0                      17.0
# 2                      54.0                      17.0
# 3                      54.0                      17.0
# 4                      54.0                      17.0
#
#    news_coverage_volatility_index
# 0                            30.0
# 1                            30.0
# 2                            30.0
# 3                            30.0
# 4                            30.0
#
# [5 rows x 108 columns]

# %%
# Load and clean stock data
stock_df = pd.read_csv("unified_stock_data.csv")
stock_df.rename(columns={"Date": "date"}, inplace=True)
stock_df['date'] = pd.to_datetime(stock_df['date'])

# %%
stock_df.head()
# Out:
#         date  Open_CSCO  High_CSCO  Low_CSCO  Close_CSCO  Adj Close_CSCO  \
# 0 2000-01-03   54.96875    55.1250  51.78125    54.03125       35.572937
# 1 2000-01-04   52.75000    53.5000  50.87500    51.00000       33.577236
# 2 2000-01-05   50.03125    52.2500  48.62500    50.84375       33.474365
# 3 2000-01-06   50.40625    50.9375  49.31250    50.00000       32.918861
# 4 2000-01-07   49.68750    53.0000  49.68750    52.93750       34.852848
#
#    Volume_CSCO  Open_ADBE  High_ADBE   Low_ADBE  ...  Low_FORD  Close_FORD  \
# 0     53076000  16.812500  16.875000  16.062500  ...    28.125      30.625
# 1     50805600  15.750000  16.453125  14.984375  ...    26.250      30.625
# 2     68524000  14.562500  15.687500  14.562500  ...    26.250      28.750
# 3     48242600  15.359375  15.656250  15.156250  ...    26.250      27.500
# 4     62260600  15.390625  16.187500  15.218750  ...    26.250      28.750
#
#    Adj Close_FORD  Volume_FORD  Open_AAPL  High_AAPL  Low_AAPL  Close_AAPL  \
# 0          30.625         4260   0.936384   1.004464  0.907924    0.999442
# 1          30.625         2360   0.966518   0.987723  0.903460    0.915179
# 2          28.750          720   0.926339   0.987165  0.919643    0.928571
# 3          27.500         4540   0.947545   0.955357  0.848214    0.848214
# 4          28.750         4330   0.861607   0.901786  0.852679    0.888393
#
#    Adj Close_AAPL  Volume_AAPL
# 0        0.842151    535796800
# 1        0.771149    512377600
# 2        0.782433    778321600
# 3        0.714723    767972800
# 4        0.748578    460734400
#
# [5 rows x 49 columns]

# %%
# Load and clean financial data
financial_df = pd.read_csv("financial_data_cleaned2.csv")
financial_df.rename(columns={"Date": "date"}, inplace=True)
financial_df['date'] = pd.to_datetime(financial_df['date'])

# %%
financial_df.head()
# Out:
#         date  Adj Close_^GSPC  Adj Close_^IXIC  Adj Close_^VIX  Bond Yields  \
# 0 2004-01-01      1111.920044      2003.369995       18.309999         4.27
# 1 2004-01-02      1108.479980      2006.680054       18.219999         4.38
# 2 2004-01-05      1122.219971      2047.359985       17.490000         4.41
# 3 2004-01-06      1123.670044      2057.370117       16.730000         4.29
# 4 2004-01-07      1126.329956      2077.679932       15.500000         4.27
#
#    Inflation  Unemployment  Interest Rate  Consumer Sentiment        GDP  ...  \
# 0      186.3           5.7            1.0               103.8  11923.447  ...
# 1      186.3           5.7            1.0               103.8  11923.447  ...
# 2      186.3           5.7            1.0               103.8  11923.447  ...
# 3      186.3           5.7            1.0               103.8  11923.447  ...
# 4      186.3           5.7            1.0               103.8  11923.447  ...
#
#    Interest Rate_lag30_lag90_lag180_rolling90_rolling180  \
# 0                                           1.746524
# 1                                           1.745816
# 2                                           1.745106
# 3                                           1.744394
# 4                                           1.743681
#
#    Consumer Sentiment_lag30_lag90_lag180_rolling90_rolling180  \
# 0                                          91.359951
# 1                                          91.332796
# 2                                          91.304673
# 3                                          91.275580
# 4                                          91.245519
#
#    GDP_lag30_lag90_lag180_rolling90_rolling180  Rolling_Std_30d  market crash  \
# 0                                 10880.208017        20.100536          31.0
# 1                                 10881.780753        19.347632          31.0
# 2                                 10883.350672        20.203467          31.0
# 3                                 10884.917773        20.939856          31.0
# 4                                 10886.482057        21.774041          31.0
#
#    buy gold  recession  inflation  stock market crash  interest rates
# 0      28.0        4.0       49.0                 7.0            61.0
# 1      28.0        4.0       49.0                 7.0            61.0
# 2      28.0        4.0       49.0                 7.0            61.0
# 3      28.0        4.0       49.0                 7.0            61.0
# 4      28.0        4.0       49.0                 7.0            61.0
#
# [5 rows x 203 columns]

# %%
# Merge all sources
merged = merge_on_date(fred_df, stock_df)
merged = merge_on_date(merged, financial_df)

# %%
merged.head()
# Out:
#         date  layman__oil_price  layman__gas_price  layman__mortgage_rate  \
# 0 1997-01-01              27.65              1.316                   8.25
# 1 1997-02-01              27.65              1.316                   8.25
# 2 1997-03-01              27.65              1.316                   8.25
# 3 1997-04-01              27.65              1.316                   8.25
# 4 1997-05-01              27.65              1.316                   8.25
#
#    layman__housing_prices  layman__grocery_index  layman__retail_sales  \
# 0                   100.0                  166.3              268044.0
# 1                   100.0                  166.3              268044.0
# 2                   100.0                  166.3              268044.0
# 3                   100.0                  166.3              268044.0
# 4                   100.0                  166.3              268044.0
#
#    layman__electricity_cost_index  layman__used_car_prices  \
# 0                           117.3                    153.9
# 1                           117.3                    153.9
# 2                           117.3                    153.9
# 3                           117.3                    153.9
# 4                           117.3                    153.9
#
#    layman__minimum_wage_trend  ...  \
# 0                        5.15  ...
# 1                        5.15  ...
# 2                        5.15  ...
# 3                        5.15  ...
# 4                        5.15  ...
#
#    Interest Rate_lag30_lag90_lag180_rolling90_rolling180  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Consumer Sentiment_lag30_lag90_lag180_rolling90_rolling180  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    GDP_lag30_lag90_lag180_rolling90_rolling180  Rolling_Std_30d  market crash  \
# 0                                          NaN              NaN           NaN
# 1                                          NaN              NaN           NaN
# 2                                          NaN              NaN           NaN
# 3                                          NaN              NaN           NaN
# 4                                          NaN              NaN           NaN
#
#    buy gold  recession  inflation  stock market crash  interest rates
# 0       NaN        NaN        NaN                 NaN             NaN
# 1       NaN        NaN        NaN                 NaN             NaN
# 2       NaN        NaN        NaN                 NaN             NaN
# 3       NaN        NaN        NaN                 NaN             NaN
# 4       NaN        NaN        NaN                 NaN             NaN
#
# [5 rows x 358 columns]

# %%
# --- Add mutual fund NAV pivoted data ---
mutual_df = pd.read_csv("cleaned_mutual_fund_nav copy.csv")
mutual_df.columns = [col.strip() for col in mutual_df.columns]
mutual_df['NAV__Scheme Code'] = mutual_df['NAV__Scheme Code'].astype(str)
mutual_df['date'] = pd.to_datetime(mutual_df['date'])

mf_pivot = mutual_df.pivot(index='date', columns='NAV__Scheme Code', values='NAV__Net Asset Value')
mf_pivot.columns = [f"nav_{code}" for code in mf_pivot.columns]
mf_pivot = mf_pivot.reset_index()

merged = merge_on_date(merged, mf_pivot)
merged = interpolate_and_clean(merged)

# %%
merged.head()
# Out:
#         date  layman__oil_price  layman__gas_price  layman__mortgage_rate  \
# 0 1997-01-01              27.65              1.316                   8.25
# 1 1997-02-01              27.65              1.316                   8.25
# 2 1997-03-01              27.65              1.316                   8.25
# 3 1997-04-01              27.65              1.316                   8.25
# 4 1997-05-01              27.65              1.316                   8.25
#
#    layman__housing_prices  layman__grocery_index  layman__retail_sales  \
# 0                   100.0                  166.3              268044.0
# 1                   100.0                  166.3              268044.0
# 2                   100.0                  166.3              268044.0
# 3                   100.0                  166.3              268044.0
# 4                   100.0                  166.3              268044.0
#
#    layman__electricity_cost_index  layman__used_car_prices  \
# 0                           117.3                    153.9
# 1                           117.3                    153.9
# 2                           117.3                    153.9
# 3                           117.3                    153.9
# 4                           117.3                    153.9
#
#    layman__minimum_wage_trend  ...  nav_153434  nav_153435  nav_153436  \
# 0                        5.15  ...         9.8     35.1732     10.0213
# 1                        5.15  ...         9.8     35.1732     10.0213
# 2                        5.15  ...         9.8     35.1732     10.0213
# 3                        5.15  ...         9.8     35.1732     10.0213
# 4                        5.15  ...         9.8     35.1732     10.0213
#
#    nav_153438  nav_153441  nav_153442  nav_153443  nav_153444  nav_153445  \
# 0    1002.237      10.019     10.0197      10.083     10.0832     10.0819
# 1    1002.237      10.019     10.0197      10.083     10.0832     10.0819
# 2    1002.237      10.019     10.0197      10.083     10.0832     10.0819
# 3    1002.237      10.019     10.0197      10.083     10.0832     10.0819
# 4    1002.237      10.019     10.0197      10.083     10.0832     10.0819
#
#    nav_153451
# 0   1002.7085
# 1   1002.7085
# 2   1002.7085
# 3   1002.7085
# 4   1002.7085
#
# [5 rows x 14334 columns]

# %%
# Save to disk
# merged.to_csv("final_merged_dataset.csv", index=False)
merged.to_parquet("final_merged_dataset.parquet", index=False)
print("Final dataset saved to final_merged_dataset.parquet")
# Out:
# Final dataset saved to final_merged_dataset.parquet

# %%
merged.head()
# Out:
#         date  layman__oil_price  layman__gas_price  layman__mortgage_rate  \
# 0 1997-01-01              27.65              1.316                   8.25
# 1 1997-02-01              27.65              1.316                   8.25
# 2 1997-03-01              27.65              1.316                   8.25
# 3 1997-04-01              27.65              1.316                   8.25
# 4 1997-05-01              27.65              1.316                   8.25
#
#    layman__housing_prices  layman__grocery_index  layman__retail_sales  \
# 0                   100.0                  166.3              268044.0
# 1                   100.0                  166.3              268044.0
# 2                   100.0                  166.3              268044.0
# 3                   100.0                  166.3              268044.0
# 4                   100.0                  166.3              268044.0
#
#    layman__electricity_cost_index  layman__used_car_prices  \
# 0                           117.3                    153.9
# 1                           117.3                    153.9
# 2                           117.3                    153.9
# 3                           117.3                    153.9
# 4                           117.3                    153.9
#
#    layman__minimum_wage_trend  ...  nav_153434  nav_153435  nav_153436  \
# 0                        5.15  ...         9.8     35.1732     10.0213
# 1                        5.15  ...         9.8     35.1732     10.0213
# 2                        5.15  ...         9.8     35.1732     10.0213
# 3                        5.15  ...         9.8     35.1732     10.0213
# 4                        5.15  ...         9.8     35.1732     10.0213
#
#    nav_153438  nav_153441  nav_153442  nav_153443  nav_153444  nav_153445  \
# 0    1002.237      10.019     10.0197      10.083     10.0832     10.0819
# 1    1002.237      10.019     10.0197      10.083     10.0832     10.0819
# 2    1002.237      10.019     10.0197      10.083     10.0832     10.0819
# 3    1002.237      10.019     10.0197      10.083     10.0832     10.0819
# 4    1002.237      10.019     10.0197      10.083     10.0832     10.0819
#
#    nav_153451
# 0   1002.7085
# 1   1002.7085
# 2   1002.7085
# 3   1002.7085
# 4   1002.7085
#
# [5 rows x 14334 columns]
