# %% [markdown]
# # 📊 PCA-Based Visual Forecast Dataset Generator
#
# This notebook/script creates a training dataset for a CNN-based macroeconomic climate forecasting model.
#
# ## 🎯 Objective:
# To generate realistic, interpretable training pairs for a neural network that learns to forecast future macroeconomic trends — not as numeric values, but as **plausible visual trajectories**.
#
# ## 🧠 How It Works:
# 1. **Input Dataset**: Uses `selected_features_83_w_rare_events.csv`, containing 83 macro/market features with monthly timestamps.
# 2. **PCA Transformation**: Reduces these features into the top 15 principal components (PC0–PC14), preserving interpretable latent structure.
# 3. **Windowing**:
#    - Input: 15-year rolling window (180 months) of PCA components
#    - Output: Corresponding next 2 years (24 months) and 5 years (60 months)
# 4. **Graph Imaging**:
#    - Each input/output pair is visualized as a line plot showing all 15 PCs
#    - Saved as PNGs for use as training data for a CNN
# 5. **Metadata Export**: A `pairs_metadata.csv` file logs the date ranges and paths for each image pair.
#
# ## 📦 Output Folder Structure:

# %%
# pca_graph_pairs/
# ├── inputs/             ← Graphs of past 15-year PCA sequences (PC0–PC14, legended)
# ├── outputs_2yr/        ← Graphs of next 2-year PCA projections (ground truth)
# ├── outputs_5yr/        ← Graphs of next 5-year PCA projections (ground truth)
# └── pairs_metadata.csv  ← Table with image paths, forecast windows, and actual date ranges

# %% [markdown]
# ## 💡 Next Step:
# Train a CNN to take these input images and learn to paint plausible future macroeconomic trajectories — enabling "visual latent forecasting" of economic climate drift.

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from pathlib import Path
from matplotlib.cm import get_cmap
import gc
import csv

# --- Step 1: Load dataset ---
df = pd.read_csv("selected_features_83_w_rare_events.csv", parse_dates=["date"])
df = df.sort_values("date")

# %%
# --- Step 2: Prepare features for PCA ---
flag_cols = [col for col in df.columns if "flag" in col.lower()]
macro_cols = [col for col in df.select_dtypes(include=[float, int]).columns if col not in flag_cols]
X = df[macro_cols]
X_scaled = StandardScaler().fit_transform(X)

# %%
# --- Step 3: Run PCA and store top 15 components ---
pca = PCA(n_components=15)
pca_data = pca.fit_transform(X_scaled)
pc_cols = [f"PC{i}" for i in range(15)]
df_pca = pd.DataFrame(pca_data, columns=pc_cols)
df_pca["date"] = df["date"].values

# %%
# --- Step 4: Setup output folders ---
output_root = Path("pca_graph_pairs")
(output_root / "inputs").mkdir(parents=True, exist_ok=True)
(output_root / "outputs_2yr").mkdir(exist_ok=True)
(output_root / "outputs_5yr").mkdir(exist_ok=True)

# %%
def generate_pca_image_batch(
    df_pca,
    output_root,
    pc_cols,
    start_idx=0,
    max_pairs=200,
    window_years=15,
    forecast_years=(2, 5),
    freq_per_year=12
):
    """
    Generates PCA input/output image pairs in batches for CNN training.

    Parameters:
    - df_pca: DataFrame with date + PC0–PC14
    - output_root: Path to base directory for image storage
    - pc_cols: list of PCA column names (e.g., PC0–PC14)
    - start_idx: starting index into df_pca
    - max_pairs: max total (input → output) image pairs per call
    - window_years: years in each input chunk
    - forecast_years: list of forecast durations (e.g., [2, 5])
    - freq_per_year: default 12 (monthly data)
    """
    colors = get_cmap("tab20").colors[:len(pc_cols)]
    input_len = window_years * freq_per_year
    pairs = []

    total_generated = 0
    for i in range(start_idx, len(df_pca) - input_len - max(forecast_years) * freq_per_year):
        input_chunk = df_pca.iloc[i : i + input_len]

        for f_yrs in forecast_years:
            forecast_len = f_yrs * freq_per_year
            output_chunk = df_pca.iloc[i + input_len : i + input_len + forecast_len]

            # File naming based on date
            start = input_chunk["date"].iloc[0].strftime("%Y%m")
            end = output_chunk["date"].iloc[-1].strftime("%Y%m")
            base_name = f"chunk_{start}_to_{end}_{f_yrs}yr"

            input_path = Path(output_root) / "inputs" / f"{base_name}.png"
            output_path = Path(output_root) / f"outputs_{f_yrs}yr" / f"{base_name}.png"

            # Plot input
            plt.figure(figsize=(6, 3))
            for j, col in enumerate(pc_cols):
                plt.plot(input_chunk["date"], input_chunk[col], label=col, color=colors[j])
            plt.title(f"Input: {input_chunk['date'].iloc[0].year}–{input_chunk['date'].iloc[-1].year}")
            plt.legend(loc="upper left", fontsize=6, ncol=3)
            plt.xticks([]); plt.yticks([]); plt.tight_layout()
            plt.savefig(input_path, dpi=100)
            plt.close()

            # Plot output
            plt.figure(figsize=(6, 3))
            for j, col in enumerate(pc_cols):
                plt.plot(output_chunk["date"], output_chunk[col], label=col, color=colors[j])
            plt.title(f"Output: {output_chunk['date'].iloc[0].year}–{output_chunk['date'].iloc[-1].year} ({f_yrs}yr)")
            plt.legend(loc="upper left", fontsize=6, ncol=3)
            plt.xticks([]); plt.yticks([]); plt.tight_layout()
            plt.savefig(output_path, dpi=100)
            plt.close()

            # Save metadata
            pairs.append({
                "input_img": str(input_path),
                "output_img": str(output_path),
                "forecast_years": f_yrs,
                "input_start": input_chunk["date"].iloc[0],
                "input_end": input_chunk["date"].iloc[-1],
                "output_start": output_chunk["date"].iloc[0],
                "output_end": output_chunk["date"].iloc[-1],
            })

            total_generated += 1
            if total_generated >= max_pairs:
                gc.collect()
                print(f"✅ Generated {total_generated} pairs (from index {start_idx})")
                return pairs, i + 1  # return new start index

    gc.collect()
    print(f"✅ Completed entire pass from index {start_idx}")
    return pairs, len(df_pca)

# %%
# # --- Setup paths ---
# output_root = Path("pca_graph_pairs")
# (output_root / "inputs").mkdir(parents=True, exist_ok=True)
# (output_root / "outputs_2yr").mkdir(exist_ok=True)
# (output_root / "outputs_5yr").mkdir(exist_ok=True)
# meta_path = output_root / "pairs_metadata.csv"

# # --- Initialize PCA columns ---
# pc_cols = [f"PC{i}" for i in range(15)]

# # --- Initialize metadata file (only if first run) ---
# if not meta_path.exists():
#     with open(meta_path, "w", newline="") as f:
#         writer = csv.DictWriter(f, fieldnames=[
#             "input_img", "output_img", "forecast_years",
#             "input_start", "input_end", "output_start", "output_end"
#         ])
#         writer.writeheader()

# # --- Generate in safe batches ---
# start_idx = 0
# while start_idx < len(df_pca):
#     batch, start_idx = generate_pca_image_batch(
#         df_pca=df_pca,
#         output_root=output_root,
#         pc_cols=pc_cols,
#         start_idx=start_idx,
#         max_pairs=50  # 👈 smaller is safer (reduce to 25 if needed)
#     )

#     if len(batch) == 0:
#         print("🛑 No more valid image pairs to generate.")
#         break

#     # Append this batch directly to the CSV file
#     with open(meta_path, "a", newline="") as f:
#         writer = csv.DictWriter(f, fieldnames=batch[0].keys())
#         writer.writerows(batch)

#     print(f"✅ Appended {len(batch)} pairs. Current index: {start_idx}")

#     # 💣 Free up memory before next round
#     del batch
#     gc.collect()

# %%
import gc
import csv
import matplotlib
matplotlib.use("Agg")  # Headless, fast plotting backend

from pathlib import Path
from tqdm import tqdm

# --- Setup paths ---
output_root = Path("pca_graph_pairs")
(output_root / "inputs").mkdir(parents=True, exist_ok=True)
(output_root / "outputs_2yr").mkdir(exist_ok=True)
(output_root / "outputs_5yr").mkdir(exist_ok=True)
meta_path = output_root / "pairs_metadata.csv"

# --- Initialize PCA columns ---
pc_cols = [f"PC{i}" for i in range(15)]

# --- Initialize metadata file (only if first run) ---
if not meta_path.exists():
    with open(meta_path, "w", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=[
            "input_img", "output_img", "forecast_years",
            "input_start", "input_end", "output_start", "output_end"
        ])
        writer.writeheader()

# --- Generate in safe, memory-lean batches ---
start_idx = 0
while start_idx < len(df_pca):
    try:
        # Generate one safe batch
        batch, start_idx = generate_pca_image_batch(
            df_pca=df_pca,
            output_root=output_root,
            pc_cols=pc_cols,
            start_idx=start_idx,
            max_pairs=25  # 🔥 Lower for safer memory footprint
        )

        # No more images to generate
        if len(batch) == 0:
            print("🛑 No more valid image pairs to generate.")
            break

        # Append metadata to CSV immediately
        with open(meta_path, "a", newline="") as f:
            writer = csv.DictWriter(f, fieldnames=batch[0].keys())
            writer.writerows(batch)
            f.flush()  # Ensure metadata is written immediately

        print(f"✅ Appended {len(batch)} pairs. Current index: {start_idx}")

        # 💣 Clear memory after each batch
        del batch
        gc.collect()

    except Exception as e:
        print(f"❌ Error at index {start_idx}: {e}")
        gc.collect()
        break
# Out:
# /var/folders/bq/_yk5zsn90t11g7lt1yn4v9w40000gn/T/ipykernel_90048/2743475100.py:24: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = get_cmap("tab20").colors[:len(pc_cols)]
# ✅ Generated 25 pairs (from index 0)
# ✅ Appended 25 pairs. Current index: 13
# ✅ Generated 25 pairs (from index 13)
# ✅ Appended 25 pairs. Current index: 26
# ✅ Generated 25 pairs (from index 26)
# ✅ Appended 25 pairs. Current index: 39
# ✅ Generated 25 pairs (from index 39)
# ✅ Appended 25 pairs. Current index: 52
# ✅ Generated 25 pairs (from index 52)
# ✅ Appended 25 pairs. Current index: 65
# ✅ Generated 25 pairs (from index 65)
# ✅ Appended 25 pairs. Current index: 78
# ✅ Generated 25 pairs (from index 78)
# ✅ Appended 25 pairs. Current index: 91
# ✅ Generated 25 pairs (from index 91)
# ✅ Appended 25 pairs. Current index: 104
# ✅ Generated 25 pairs (from index 104)
# ✅ Appended 25 pairs. Current index: 117
# ✅ Generated 25 pairs (from index 117)
# ✅ Appended 25 pairs. Current index: 130
# ✅ Generated 25 pairs (from index 130)
# ✅ Appended 25 pairs. Current index: 143
# ✅ Generated 25 pairs (from index 143)
# ✅ Appended 25 pairs. Current index: 156
# ✅ Generated 25 pairs (from index 156)
# ✅ Appended 25 pairs. Current index: 169
# ✅ Generated 25 pairs (from index 169)
# ✅ Appended 25 pairs. Current index: 182
# ✅ Generated 25 pairs (from index 182)
# ✅ Appended 25 pairs. Current index: 195
# ✅ Generated 25 pairs (from index 195)
# ✅ Appended 25 pairs. Current index: 208
# ✅ Generated 25 pairs (from index 208)
# ✅ Appended 25 pairs. Current index: 221
# ✅ Generated 25 pairs (from index 221)
# ✅ Appended 25 pairs. Current index: 234
# ✅ Generated 25 pairs (from index 234)
# ✅ Appended 25 pairs. Current index: 247
# ✅ Generated 25 pairs (from index 247)
# ✅ Appended 25 pairs. Current index: 260
# ✅ Generated 25 pairs (from index 260)
# ✅ Appended 25 pairs. Current index: 273
# ✅ Generated 25 pairs (from index 273)
# ✅ Appended 25 pairs. Current index: 286
# ✅ Generated 25 pairs (from index 286)
# ✅ Appended 25 pairs. Current index: 299
# ✅ Generated 25 pairs (from index 299)
# ✅ Appended 25 pairs. Current index: 312
# ✅ Generated 25 pairs (from index 312)
# ✅ Appended 25 pairs. Current index: 325
# ✅ Generated 25 pairs (from index 325)
# ✅ Appended 25 pairs. Current index: 338
# ✅ Generated 25 pairs (from index 338)
# ✅ Appended 25 pairs. Current index: 351
# ✅ Generated 25 pairs (from index 351)
# ✅ Appended 25 pairs. Current index: 364
# ✅ Generated 25 pairs (from index 364)
# ✅ Appended 25 pairs. Current index: 377
# ✅ Generated 25 pairs (from index 377)
# ✅ Appended 25 pairs. Current index: 390
# ✅ Generated 25 pairs (from index 390)
# ✅ Appended 25 pairs. Current index: 403
# ✅ Generated 25 pairs (from index 403)
# ✅ Appended 25 pairs. Current index: 416
# ✅ Generated 25 pairs (from index 416)
# ✅ Appended 25 pairs. Current index: 429
# ✅ Generated 25 pairs (from index 429)
# ✅ Appended 25 pairs. Current index: 442
# ✅ Generated 25 pairs (from index 442)
# ✅ Appended 25 pairs. Current index: 455
# ✅ Generated 25 pairs (from index 455)
# ✅ Appended 25 pairs. Current index: 468
# ✅ Generated 25 pairs (from index 468)
# ✅ Appended 25 pairs. Current index: 481
# ✅ Generated 25 pairs (from index 481)
# ✅ Appended 25 pairs. Current index: 494
# ✅ Generated 25 pairs (from index 494)
# ✅ Appended 25 pairs. Current index: 507
# ✅ Generated 25 pairs (from index 507)
# ✅ Appended 25 pairs. Current index: 520
# ✅ Generated 25 pairs (from index 520)
# ✅ Appended 25 pairs. Current index: 533
# ✅ Generated 25 pairs (from index 533)
# ✅ Appended 25 pairs. Current index: 546
# ✅ Generated 25 pairs (from index 546)
# ✅ Appended 25 pairs. Current index: 559
# ✅ Generated 25 pairs (from index 559)
# ✅ Appended 25 pairs. Current index: 572
# ✅ Generated 25 pairs (from index 572)
# ✅ Appended 25 pairs. Current index: 585
# ✅ Generated 25 pairs (from index 585)
# ✅ Appended 25 pairs. Current index: 598
# ✅ Generated 25 pairs (from index 598)
# ✅ Appended 25 pairs. Current index: 611
# ✅ Generated 25 pairs (from index 611)
# ✅ Appended 25 pairs. Current index: 624
# ✅ Generated 25 pairs (from index 624)
# ✅ Appended 25 pairs. Current index: 637
# ✅ Generated 25 pairs (from index 637)
# ✅ Appended 25 pairs. Current index: 650
# ✅ Generated 25 pairs (from index 650)
# ✅ Appended 25 pairs. Current index: 663
# ✅ Generated 25 pairs (from index 663)
# ✅ Appended 25 pairs. Current index: 676
# ✅ Generated 25 pairs (from index 676)
# ✅ Appended 25 pairs. Current index: 689
# ✅ Generated 25 pairs (from index 689)
# ✅ Appended 25 pairs. Current index: 702
# ✅ Generated 25 pairs (from index 702)
# ✅ Appended 25 pairs. Current index: 715
# ✅ Generated 25 pairs (from index 715)
# ✅ Appended 25 pairs. Current index: 728
# ✅ Generated 25 pairs (from index 728)
# ✅ Appended 25 pairs. Current index: 741
# ✅ Generated 25 pairs (from index 741)
# ✅ Appended 25 pairs. Current index: 754
# ✅ Generated 25 pairs (from index 754)
# ✅ Appended 25 pairs. Current index: 767
# ✅ Generated 25 pairs (from index 767)
# ✅ Appended 25 pairs. Current index: 780
# ✅ Generated 25 pairs (from index 780)
# ✅ Appended 25 pairs. Current index: 793
# ✅ Generated 25 pairs (from index 793)
# ✅ Appended 25 pairs. Current index: 806
# ✅ Generated 25 pairs (from index 806)
# ✅ Appended 25 pairs. Current index: 819
# ✅ Generated 25 pairs (from index 819)
# ✅ Appended 25 pairs. Current index: 832
# ✅ Generated 25 pairs (from index 832)
# ✅ Appended 25 pairs. Current index: 845
# ✅ Generated 25 pairs (from index 845)
# ✅ Appended 25 pairs. Current index: 858
# ✅ Generated 25 pairs (from index 858)
# ✅ Appended 25 pairs. Current index: 871
# ✅ Generated 25 pairs (from index 871)
# ✅ Appended 25 pairs. Current index: 884
# ✅ Generated 25 pairs (from index 884)
# ✅ Appended 25 pairs. Current index: 897
# ✅ Generated 25 pairs (from index 897)
# ✅ Appended 25 pairs. Current index: 910
# ✅ Generated 25 pairs (from index 910)
# ✅ Appended 25 pairs. Current index: 923
# ✅ Generated 25 pairs (from index 923)
# ✅ Appended 25 pairs. Current index: 936
# ✅ Generated 25 pairs (from index 936)
# ✅ Appended 25 pairs. Current index: 949
# ✅ Generated 25 pairs (from index 949)
# ✅ Appended 25 pairs. Current index: 962
# ✅ Generated 25 pairs (from index 962)
# ✅ Appended 25 pairs. Current index: 975
# ✅ Generated 25 pairs (from index 975)
# ✅ Appended 25 pairs. Current index: 988
# ✅ Generated 25 pairs (from index 988)
# ✅ Appended 25 pairs. Current index: 1001
# ✅ Generated 25 pairs (from index 1001)
# ✅ Appended 25 pairs. Current index: 1014
# ✅ Generated 25 pairs (from index 1014)
# ✅ Appended 25 pairs. Current index: 1027
# ✅ Generated 25 pairs (from index 1027)
# ✅ Appended 25 pairs. Current index: 1040
# ✅ Generated 25 pairs (from index 1040)
# ✅ Appended 25 pairs. Current index: 1053
# ✅ Generated 25 pairs (from index 1053)
# ✅ Appended 25 pairs. Current index: 1066
# ✅ Generated 25 pairs (from index 1066)
# ✅ Appended 25 pairs. Current index: 1079
# ✅ Generated 25 pairs (from index 1079)
# ✅ Appended 25 pairs. Current index: 1092
# ✅ Generated 25 pairs (from index 1092)
# ✅ Appended 25 pairs. Current index: 1105
# ✅ Generated 25 pairs (from index 1105)
# ✅ Appended 25 pairs. Current index: 1118
# ✅ Generated 25 pairs (from index 1118)
# ✅ Appended 25 pairs. Current index: 1131
# ✅ Generated 25 pairs (from index 1131)
# ✅ Appended 25 pairs. Current index: 1144
# ✅ Generated 25 pairs (from index 1144)
# ✅ Appended 25 pairs. Current index: 1157
# ✅ Generated 25 pairs (from index 1157)
# ✅ Appended 25 pairs. Current index: 1170
# ✅ Generated 25 pairs (from index 1170)
# ✅ Appended 25 pairs. Current index: 1183
# ✅ Generated 25 pairs (from index 1183)
# ✅ Appended 25 pairs. Current index: 1196
# ✅ Generated 25 pairs (from index 1196)
# ✅ Appended 25 pairs. Current index: 1209
# ✅ Generated 25 pairs (from index 1209)
# ✅ Appended 25 pairs. Current index: 1222
# ✅ Generated 25 pairs (from index 1222)
# ✅ Appended 25 pairs. Current index: 1235
# ✅ Generated 25 pairs (from index 1235)
# ✅ Appended 25 pairs. Current index: 1248
# ✅ Generated 25 pairs (from index 1248)
# ✅ Appended 25 pairs. Current index: 1261
# ✅ Generated 25 pairs (from index 1261)
# ✅ Appended 25 pairs. Current index: 1274
# ✅ Generated 25 pairs (from index 1274)
# ✅ Appended 25 pairs. Current index: 1287
# ✅ Generated 25 pairs (from index 1287)
# ✅ Appended 25 pairs. Current index: 1300
# ✅ Generated 25 pairs (from index 1300)
# ✅ Appended 25 pairs. Current index: 1313
# ✅ Generated 25 pairs (from index 1313)
# ✅ Appended 25 pairs. Current index: 1326
# ✅ Generated 25 pairs (from index 1326)
# ✅ Appended 25 pairs. Current index: 1339
# ✅ Generated 25 pairs (from index 1339)
# ✅ Appended 25 pairs. Current index: 1352
# ✅ Generated 25 pairs (from index 1352)
# ✅ Appended 25 pairs. Current index: 1365
# ✅ Generated 25 pairs (from index 1365)
# ✅ Appended 25 pairs. Current index: 1378
# ✅ Generated 25 pairs (from index 1378)
# ✅ Appended 25 pairs. Current index: 1391
# ✅ Generated 25 pairs (from index 1391)
# ✅ Appended 25 pairs. Current index: 1404
# ✅ Generated 25 pairs (from index 1404)
# ✅ Appended 25 pairs. Current index: 1417
# ✅ Generated 25 pairs (from index 1417)
# ✅ Appended 25 pairs. Current index: 1430
# ✅ Generated 25 pairs (from index 1430)
# ✅ Appended 25 pairs. Current index: 1443
# ✅ Generated 25 pairs (from index 1443)
# ✅ Appended 25 pairs. Current index: 1456
# ✅ Generated 25 pairs (from index 1456)
# ✅ Appended 25 pairs. Current index: 1469
# ✅ Generated 25 pairs (from index 1469)
# ✅ Appended 25 pairs. Current index: 1482
# ✅ Generated 25 pairs (from index 1482)
# ✅ Appended 25 pairs. Current index: 1495
# ✅ Generated 25 pairs (from index 1495)
# ✅ Appended 25 pairs. Current index: 1508
# ✅ Generated 25 pairs (from index 1508)
# ✅ Appended 25 pairs. Current index: 1521
# ✅ Generated 25 pairs (from index 1521)
# ✅ Appended 25 pairs. Current index: 1534
# ✅ Generated 25 pairs (from index 1534)
# ✅ Appended 25 pairs. Current index: 1547
# ✅ Generated 25 pairs (from index 1547)
# ✅ Appended 25 pairs. Current index: 1560
# ✅ Generated 25 pairs (from index 1560)
# ✅ Appended 25 pairs. Current index: 1573
# ✅ Generated 25 pairs (from index 1573)
# ✅ Appended 25 pairs. Current index: 1586
# ✅ Generated 25 pairs (from index 1586)
# ✅ Appended 25 pairs. Current index: 1599
# ✅ Generated 25 pairs (from index 1599)
# ✅ Appended 25 pairs. Current index: 1612
# ✅ Generated 25 pairs (from index 1612)
# ✅ Appended 25 pairs. Current index: 1625
# ✅ Generated 25 pairs (from index 1625)
# ✅ Appended 25 pairs. Current index: 1638
# ✅ Generated 25 pairs (from index 1638)
# ✅ Appended 25 pairs. Current index: 1651
# ✅ Generated 25 pairs (from index 1651)
# ✅ Appended 25 pairs. Current index: 1664
# ✅ Generated 25 pairs (from index 1664)
# ✅ Appended 25 pairs. Current index: 1677
# ✅ Generated 25 pairs (from index 1677)
# ✅ Appended 25 pairs. Current index: 1690
# ✅ Generated 25 pairs (from index 1690)
# ✅ Appended 25 pairs. Current index: 1703
# ✅ Generated 25 pairs (from index 1703)
# ✅ Appended 25 pairs. Current index: 1716
# ✅ Generated 25 pairs (from index 1716)
# ✅ Appended 25 pairs. Current index: 1729
# ✅ Generated 25 pairs (from index 1729)
# ✅ Appended 25 pairs. Current index: 1742
# ✅ Generated 25 pairs (from index 1742)
# ✅ Appended 25 pairs. Current index: 1755
# ✅ Generated 25 pairs (from index 1755)
# ✅ Appended 25 pairs. Current index: 1768
# ✅ Generated 25 pairs (from index 1768)
# ✅ Appended 25 pairs. Current index: 1781
# ✅ Generated 25 pairs (from index 1781)
# ✅ Appended 25 pairs. Current index: 1794
# ✅ Generated 25 pairs (from index 1794)
# ✅ Appended 25 pairs. Current index: 1807
# ✅ Generated 25 pairs (from index 1807)
# ✅ Appended 25 pairs. Current index: 1820
# ✅ Generated 25 pairs (from index 1820)
# ✅ Appended 25 pairs. Current index: 1833
# ✅ Generated 25 pairs (from index 1833)
# ✅ Appended 25 pairs. Current index: 1846
# ✅ Generated 25 pairs (from index 1846)
# ✅ Appended 25 pairs. Current index: 1859
# ✅ Generated 25 pairs (from index 1859)
# ✅ Appended 25 pairs. Current index: 1872
# ✅ Generated 25 pairs (from index 1872)
# ✅ Appended 25 pairs. Current index: 1885
# ✅ Generated 25 pairs (from index 1885)
# ✅ Appended 25 pairs. Current index: 1898
# ✅ Generated 25 pairs (from index 1898)
# ✅ Appended 25 pairs. Current index: 1911
# ✅ Generated 25 pairs (from index 1911)
# ✅ Appended 25 pairs. Current index: 1924
# ✅ Generated 25 pairs (from index 1924)
# ✅ Appended 25 pairs. Current index: 1937
# ✅ Generated 25 pairs (from index 1937)
# ✅ Appended 25 pairs. Current index: 1950
# ✅ Generated 25 pairs (from index 1950)
# ✅ Appended 25 pairs. Current index: 1963
# ✅ Generated 25 pairs (from index 1963)
# ✅ Appended 25 pairs. Current index: 1976
# ✅ Generated 25 pairs (from index 1976)
# ✅ Appended 25 pairs. Current index: 1989
# ✅ Generated 25 pairs (from index 1989)
# ✅ Appended 25 pairs. Current index: 2002
# ✅ Generated 25 pairs (from index 2002)
# ✅ Appended 25 pairs. Current index: 2015
# ✅ Generated 25 pairs (from index 2015)
# ✅ Appended 25 pairs. Current index: 2028
# ✅ Generated 25 pairs (from index 2028)
# ✅ Appended 25 pairs. Current index: 2041
# ✅ Generated 25 pairs (from index 2041)
# ✅ Appended 25 pairs. Current index: 2054
# ✅ Generated 25 pairs (from index 2054)
# ✅ Appended 25 pairs. Current index: 2067
# ✅ Generated 25 pairs (from index 2067)
# ✅ Appended 25 pairs. Current index: 2080
# ✅ Generated 25 pairs (from index 2080)
# ✅ Appended 25 pairs. Current index: 2093
# ✅ Generated 25 pairs (from index 2093)
# ✅ Appended 25 pairs. Current index: 2106
# ✅ Generated 25 pairs (from index 2106)
# ✅ Appended 25 pairs. Current index: 2119
# ✅ Generated 25 pairs (from index 2119)
# ✅ Appended 25 pairs. Current index: 2132
# ✅ Generated 25 pairs (from index 2132)
# ✅ Appended 25 pairs. Current index: 2145
# ✅ Generated 25 pairs (from index 2145)
# ✅ Appended 25 pairs. Current index: 2158
# ✅ Generated 25 pairs (from index 2158)
# ✅ Appended 25 pairs. Current index: 2171
# ✅ Generated 25 pairs (from index 2171)
# ✅ Appended 25 pairs. Current index: 2184
# ✅ Generated 25 pairs (from index 2184)
# ✅ Appended 25 pairs. Current index: 2197
# ✅ Generated 25 pairs (from index 2197)
# ✅ Appended 25 pairs. Current index: 2210
# ✅ Generated 25 pairs (from index 2210)
# ✅ Appended 25 pairs. Current index: 2223
# ✅ Generated 25 pairs (from index 2223)
# ✅ Appended 25 pairs. Current index: 2236
# ✅ Generated 25 pairs (from index 2236)
# ✅ Appended 25 pairs. Current index: 2249
# ✅ Generated 25 pairs (from index 2249)
# ✅ Appended 25 pairs. Current index: 2262
# ✅ Generated 25 pairs (from index 2262)
# ✅ Appended 25 pairs. Current index: 2275
# ✅ Generated 25 pairs (from index 2275)
# ✅ Appended 25 pairs. Current index: 2288
# ✅ Generated 25 pairs (from index 2288)
# ✅ Appended 25 pairs. Current index: 2301
# ✅ Generated 25 pairs (from index 2301)
# ✅ Appended 25 pairs. Current index: 2314
# ✅ Generated 25 pairs (from index 2314)
# ✅ Appended 25 pairs. Current index: 2327
# ✅ Generated 25 pairs (from index 2327)
# ✅ Appended 25 pairs. Current index: 2340
# ✅ Generated 25 pairs (from index 2340)
# ✅ Appended 25 pairs. Current index: 2353
# ✅ Generated 25 pairs (from index 2353)
# ✅ Appended 25 pairs. Current index: 2366
# ✅ Generated 25 pairs (from index 2366)
# ✅ Appended 25 pairs. Current index: 2379
# ✅ Generated 25 pairs (from index 2379)
# ✅ Appended 25 pairs. Current index: 2392
# ✅ Generated 25 pairs (from index 2392)
# ✅ Appended 25 pairs. Current index: 2405
# ✅ Generated 25 pairs (from index 2405)
# ✅ Appended 25 pairs. Current index: 2418
# ✅ Generated 25 pairs (from index 2418)
# ✅ Appended 25 pairs. Current index: 2431
# ✅ Generated 25 pairs (from index 2431)
# ✅ Appended 25 pairs. Current index: 2444
# ✅ Generated 25 pairs (from index 2444)
# ✅ Appended 25 pairs. Current index: 2457
# ✅ Generated 25 pairs (from index 2457)
# ✅ Appended 25 pairs. Current index: 2470
# ✅ Generated 25 pairs (from index 2470)
# ✅ Appended 25 pairs. Current index: 2483
# ✅ Generated 25 pairs (from index 2483)
# ✅ Appended 25 pairs. Current index: 2496
# ✅ Generated 25 pairs (from index 2496)
# ✅ Appended 25 pairs. Current index: 2509
# ✅ Generated 25 pairs (from index 2509)
# ✅ Appended 25 pairs. Current index: 2522
# ✅ Generated 25 pairs (from index 2522)
# ✅ Appended 25 pairs. Current index: 2535
# ✅ Generated 25 pairs (from index 2535)
# ✅ Appended 25 pairs. Current index: 2548
# ✅ Generated 25 pairs (from index 2548)
# ✅ Appended 25 pairs. Current index: 2561
# ✅ Generated 25 pairs (from index 2561)
# ✅ Appended 25 pairs. Current index: 2574
# ✅ Generated 25 pairs (from index 2574)
# ✅ Appended 25 pairs. Current index: 2587
# ✅ Generated 25 pairs (from index 2587)
# ✅ Appended 25 pairs. Current index: 2600
# ✅ Generated 25 pairs (from index 2600)
# ✅ Appended 25 pairs. Current index: 2613
# ✅ Generated 25 pairs (from index 2613)
# ✅ Appended 25 pairs. Current index: 2626
# ✅ Generated 25 pairs (from index 2626)
# ✅ Appended 25 pairs. Current index: 2639
# ✅ Generated 25 pairs (from index 2639)
# ✅ Appended 25 pairs. Current index: 2652
# ✅ Generated 25 pairs (from index 2652)
# ✅ Appended 25 pairs. Current index: 2665
# ✅ Generated 25 pairs (from index 2665)
# ✅ Appended 25 pairs. Current index: 2678
# ✅ Generated 25 pairs (from index 2678)
# ✅ Appended 25 pairs. Current index: 2691
# ✅ Generated 25 pairs (from index 2691)
# ✅ Appended 25 pairs. Current index: 2704
# ✅ Generated 25 pairs (from index 2704)
# ✅ Appended 25 pairs. Current index: 2717
# ✅ Generated 25 pairs (from index 2717)
# ✅ Appended 25 pairs. Current index: 2730
# ✅ Generated 25 pairs (from index 2730)
# ✅ Appended 25 pairs. Current index: 2743
# ✅ Generated 25 pairs (from index 2743)
# ✅ Appended 25 pairs. Current index: 2756
# ✅ Generated 25 pairs (from index 2756)
# ✅ Appended 25 pairs. Current index: 2769
# ✅ Generated 25 pairs (from index 2769)
# ✅ Appended 25 pairs. Current index: 2782
# ✅ Generated 25 pairs (from index 2782)
# ✅ Appended 25 pairs. Current index: 2795
# ✅ Generated 25 pairs (from index 2795)
# ✅ Appended 25 pairs. Current index: 2808
# ✅ Generated 25 pairs (from index 2808)
# ✅ Appended 25 pairs. Current index: 2821
# ✅ Generated 25 pairs (from index 2821)
# ✅ Appended 25 pairs. Current index: 2834
# ✅ Generated 25 pairs (from index 2834)
# ✅ Appended 25 pairs. Current index: 2847
# ✅ Generated 25 pairs (from index 2847)
# ✅ Appended 25 pairs. Current index: 2860
# ✅ Generated 25 pairs (from index 2860)
# ✅ Appended 25 pairs. Current index: 2873
# ✅ Generated 25 pairs (from index 2873)
# ✅ Appended 25 pairs. Current index: 2886
# ✅ Generated 25 pairs (from index 2886)
# ✅ Appended 25 pairs. Current index: 2899
# ✅ Generated 25 pairs (from index 2899)
# ✅ Appended 25 pairs. Current index: 2912
# ✅ Generated 25 pairs (from index 2912)
# ✅ Appended 25 pairs. Current index: 2925
# ✅ Generated 25 pairs (from index 2925)
# ✅ Appended 25 pairs. Current index: 2938
# ✅ Generated 25 pairs (from index 2938)
# ✅ Appended 25 pairs. Current index: 2951
# ✅ Generated 25 pairs (from index 2951)
# ✅ Appended 25 pairs. Current index: 2964
# ✅ Generated 25 pairs (from index 2964)
# ✅ Appended 25 pairs. Current index: 2977
# ✅ Generated 25 pairs (from index 2977)
# ✅ Appended 25 pairs. Current index: 2990
# ✅ Generated 25 pairs (from index 2990)
# ✅ Appended 25 pairs. Current index: 3003
# ✅ Generated 25 pairs (from index 3003)
# ✅ Appended 25 pairs. Current index: 3016
# ✅ Generated 25 pairs (from index 3016)
# ✅ Appended 25 pairs. Current index: 3029
# ✅ Generated 25 pairs (from index 3029)
# ✅ Appended 25 pairs. Current index: 3042
# ✅ Generated 25 pairs (from index 3042)
# ✅ Appended 25 pairs. Current index: 3055
# ✅ Generated 25 pairs (from index 3055)
# ✅ Appended 25 pairs. Current index: 3068
# ✅ Generated 25 pairs (from index 3068)
# ✅ Appended 25 pairs. Current index: 3081
# ✅ Generated 25 pairs (from index 3081)
# ✅ Appended 25 pairs. Current index: 3094
# ✅ Generated 25 pairs (from index 3094)
# ✅ Appended 25 pairs. Current index: 3107
# ✅ Generated 25 pairs (from index 3107)
# ✅ Appended 25 pairs. Current index: 3120
# ✅ Generated 25 pairs (from index 3120)
# ✅ Appended 25 pairs. Current index: 3133
# ✅ Generated 25 pairs (from index 3133)
# ✅ Appended 25 pairs. Current index: 3146
# ✅ Generated 25 pairs (from index 3146)
# ✅ Appended 25 pairs. Current index: 3159
# ✅ Generated 25 pairs (from index 3159)
# ✅ Appended 25 pairs. Current index: 3172
# ✅ Generated 25 pairs (from index 3172)
# ✅ Appended 25 pairs. Current index: 3185
# ✅ Generated 25 pairs (from index 3185)
# ✅ Appended 25 pairs. Current index: 3198
# ✅ Generated 25 pairs (from index 3198)
# ✅ Appended 25 pairs. Current index: 3211
# ✅ Generated 25 pairs (from index 3211)
# ✅ Appended 25 pairs. Current index: 3224
# ✅ Generated 25 pairs (from index 3224)
# ✅ Appended 25 pairs. Current index: 3237
# ✅ Generated 25 pairs (from index 3237)
# ✅ Appended 25 pairs. Current index: 3250
# ✅ Generated 25 pairs (from index 3250)
# ✅ Appended 25 pairs. Current index: 3263
# ✅ Generated 25 pairs (from index 3263)
# ✅ Appended 25 pairs. Current index: 3276
# ✅ Generated 25 pairs (from index 3276)
# ✅ Appended 25 pairs. Current index: 3289
# ✅ Generated 25 pairs (from index 3289)
# ✅ Appended 25 pairs. Current index: 3302
# ✅ Generated 25 pairs (from index 3302)
# ✅ Appended 25 pairs. Current index: 3315
# ✅ Generated 25 pairs (from index 3315)
# ✅ Appended 25 pairs. Current index: 3328
# ✅ Generated 25 pairs (from index 3328)
# ✅ Appended 25 pairs. Current index: 3341
# ✅ Generated 25 pairs (from index 3341)
# ✅ Appended 25 pairs. Current index: 3354
# ✅ Generated 25 pairs (from index 3354)
# ✅ Appended 25 pairs. Current index: 3367
# ✅ Generated 25 pairs (from index 3367)
# ✅ Appended 25 pairs. Current index: 3380
# ✅ Generated 25 pairs (from index 3380)
# ✅ Appended 25 pairs. Current index: 3393
# ✅ Generated 25 pairs (from index 3393)
# ✅ Appended 25 pairs. Current index: 3406
# ✅ Generated 25 pairs (from index 3406)
# ✅ Appended 25 pairs. Current index: 3419
# ✅ Generated 25 pairs (from index 3419)
# ✅ Appended 25 pairs. Current index: 3432
# ✅ Generated 25 pairs (from index 3432)
# ✅ Appended 25 pairs. Current index: 3445
# ✅ Generated 25 pairs (from index 3445)
# ✅ Appended 25 pairs. Current index: 3458
# ✅ Generated 25 pairs (from index 3458)
# ✅ Appended 25 pairs. Current index: 3471
# ✅ Generated 25 pairs (from index 3471)
# ✅ Appended 25 pairs. Current index: 3484
# ✅ Generated 25 pairs (from index 3484)
# ✅ Appended 25 pairs. Current index: 3497
# ✅ Generated 25 pairs (from index 3497)
# ✅ Appended 25 pairs. Current index: 3510
# ✅ Generated 25 pairs (from index 3510)
# ✅ Appended 25 pairs. Current index: 3523
# ✅ Generated 25 pairs (from index 3523)
# ✅ Appended 25 pairs. Current index: 3536
# ✅ Generated 25 pairs (from index 3536)
# ✅ Appended 25 pairs. Current index: 3549
# ✅ Generated 25 pairs (from index 3549)
# ✅ Appended 25 pairs. Current index: 3562
# ✅ Generated 25 pairs (from index 3562)
# ✅ Appended 25 pairs. Current index: 3575
# ✅ Generated 25 pairs (from index 3575)
# ✅ Appended 25 pairs. Current index: 3588
# ✅ Generated 25 pairs (from index 3588)
# ✅ Appended 25 pairs. Current index: 3601
# ✅ Generated 25 pairs (from index 3601)
# ✅ Appended 25 pairs. Current index: 3614
# ✅ Generated 25 pairs (from index 3614)
# ✅ Appended 25 pairs. Current index: 3627
# ✅ Generated 25 pairs (from index 3627)
# ✅ Appended 25 pairs. Current index: 3640
# ✅ Generated 25 pairs (from index 3640)
# ✅ Appended 25 pairs. Current index: 3653
# ✅ Generated 25 pairs (from index 3653)
# ✅ Appended 25 pairs. Current index: 3666
# ✅ Generated 25 pairs (from index 3666)
# ✅ Appended 25 pairs. Current index: 3679
# ✅ Generated 25 pairs (from index 3679)
# ✅ Appended 25 pairs. Current index: 3692
# ✅ Generated 25 pairs (from index 3692)
# ✅ Appended 25 pairs. Current index: 3705
# ✅ Generated 25 pairs (from index 3705)
# ✅ Appended 25 pairs. Current index: 3718
# ✅ Generated 25 pairs (from index 3718)
# ✅ Appended 25 pairs. Current index: 3731
# ✅ Generated 25 pairs (from index 3731)
# ✅ Appended 25 pairs. Current index: 3744
# ✅ Generated 25 pairs (from index 3744)
# ✅ Appended 25 pairs. Current index: 3757
# ✅ Generated 25 pairs (from index 3757)
# ✅ Appended 25 pairs. Current index: 3770
# ✅ Generated 25 pairs (from index 3770)
# ✅ Appended 25 pairs. Current index: 3783
# ✅ Generated 25 pairs (from index 3783)
# ✅ Appended 25 pairs. Current index: 3796
# ✅ Generated 25 pairs (from index 3796)
# ✅ Appended 25 pairs. Current index: 3809
# ✅ Generated 25 pairs (from index 3809)
# ✅ Appended 25 pairs. Current index: 3822
# ✅ Generated 25 pairs (from index 3822)
# ✅ Appended 25 pairs. Current index: 3835
# ✅ Generated 25 pairs (from index 3835)
# ✅ Appended 25 pairs. Current index: 3848
# ✅ Generated 25 pairs (from index 3848)
# ✅ Appended 25 pairs. Current index: 3861
# ✅ Generated 25 pairs (from index 3861)
# ✅ Appended 25 pairs. Current index: 3874
# ✅ Generated 25 pairs (from index 3874)
# ✅ Appended 25 pairs. Current index: 3887
# ✅ Generated 25 pairs (from index 3887)
# ✅ Appended 25 pairs. Current index: 3900
# ✅ Generated 25 pairs (from index 3900)
# ✅ Appended 25 pairs. Current index: 3913
# ✅ Generated 25 pairs (from index 3913)
# ✅ Appended 25 pairs. Current index: 3926
# ✅ Generated 25 pairs (from index 3926)
# ✅ Appended 25 pairs. Current index: 3939
# ✅ Generated 25 pairs (from index 3939)
# ✅ Appended 25 pairs. Current index: 3952
# ✅ Generated 25 pairs (from index 3952)
# ✅ Appended 25 pairs. Current index: 3965
# ✅ Generated 25 pairs (from index 3965)
# ✅ Appended 25 pairs. Current index: 3978
# ✅ Generated 25 pairs (from index 3978)
# ✅ Appended 25 pairs. Current index: 3991
# ✅ Generated 25 pairs (from index 3991)
# ✅ Appended 25 pairs. Current index: 4004
# ✅ Generated 25 pairs (from index 4004)
# ✅ Appended 25 pairs. Current index: 4017
# ✅ Generated 25 pairs (from index 4017)
# ✅ Appended 25 pairs. Current index: 4030
# ✅ Generated 25 pairs (from index 4030)
# ✅ Appended 25 pairs. Current index: 4043
# ✅ Generated 25 pairs (from index 4043)
# ✅ Appended 25 pairs. Current index: 4056
# ✅ Generated 25 pairs (from index 4056)
# ✅ Appended 25 pairs. Current index: 4069
# ✅ Generated 25 pairs (from index 4069)
# ✅ Appended 25 pairs. Current index: 4082
# ✅ Generated 25 pairs (from index 4082)
# ✅ Appended 25 pairs. Current index: 4095
# ✅ Generated 25 pairs (from index 4095)
# ✅ Appended 25 pairs. Current index: 4108
# ✅ Generated 25 pairs (from index 4108)
# ✅ Appended 25 pairs. Current index: 4121
# ✅ Generated 25 pairs (from index 4121)
# ✅ Appended 25 pairs. Current index: 4134
# ✅ Generated 25 pairs (from index 4134)
# ✅ Appended 25 pairs. Current index: 4147
# ✅ Generated 25 pairs (from index 4147)
# ✅ Appended 25 pairs. Current index: 4160
# ✅ Generated 25 pairs (from index 4160)
# ✅ Appended 25 pairs. Current index: 4173
# ✅ Generated 25 pairs (from index 4173)
# ✅ Appended 25 pairs. Current index: 4186
# ✅ Generated 25 pairs (from index 4186)
# ✅ Appended 25 pairs. Current index: 4199
# ✅ Generated 25 pairs (from index 4199)
# ✅ Appended 25 pairs. Current index: 4212
# ✅ Generated 25 pairs (from index 4212)
# ✅ Appended 25 pairs. Current index: 4225
# ✅ Generated 25 pairs (from index 4225)
# ✅ Appended 25 pairs. Current index: 4238
# ✅ Generated 25 pairs (from index 4238)
# ✅ Appended 25 pairs. Current index: 4251
# ✅ Generated 25 pairs (from index 4251)
# ✅ Appended 25 pairs. Current index: 4264
# ✅ Generated 25 pairs (from index 4264)
# ✅ Appended 25 pairs. Current index: 4277
# ✅ Generated 25 pairs (from index 4277)
# ✅ Appended 25 pairs. Current index: 4290
# ✅ Generated 25 pairs (from index 4290)
# ✅ Appended 25 pairs. Current index: 4303
# ✅ Generated 25 pairs (from index 4303)
# ✅ Appended 25 pairs. Current index: 4316
# ✅ Generated 25 pairs (from index 4316)
# ✅ Appended 25 pairs. Current index: 4329
# ✅ Generated 25 pairs (from index 4329)
# ✅ Appended 25 pairs. Current index: 4342
# ✅ Generated 25 pairs (from index 4342)
# ✅ Appended 25 pairs. Current index: 4355
# ✅ Generated 25 pairs (from index 4355)
# ✅ Appended 25 pairs. Current index: 4368
# ✅ Generated 25 pairs (from index 4368)
# ✅ Appended 25 pairs. Current index: 4381
# ✅ Generated 25 pairs (from index 4381)
# ✅ Appended 25 pairs. Current index: 4394
# ✅ Generated 25 pairs (from index 4394)
# ✅ Appended 25 pairs. Current index: 4407
# ✅ Generated 25 pairs (from index 4407)
# ✅ Appended 25 pairs. Current index: 4420
# ✅ Generated 25 pairs (from index 4420)
# ✅ Appended 25 pairs. Current index: 4433
# ✅ Generated 25 pairs (from index 4433)
# ✅ Appended 25 pairs. Current index: 4446
# ✅ Generated 25 pairs (from index 4446)
# ✅ Appended 25 pairs. Current index: 4459
# ✅ Generated 25 pairs (from index 4459)
# ✅ Appended 25 pairs. Current index: 4472
# ✅ Generated 25 pairs (from index 4472)
# ✅ Appended 25 pairs. Current index: 4485
# ✅ Generated 25 pairs (from index 4485)
# ✅ Appended 25 pairs. Current index: 4498
# ✅ Generated 25 pairs (from index 4498)
# ✅ Appended 25 pairs. Current index: 4511
# ✅ Generated 25 pairs (from index 4511)
# ✅ Appended 25 pairs. Current index: 4524
# ✅ Generated 25 pairs (from index 4524)
# ✅ Appended 25 pairs. Current index: 4537
# ✅ Generated 25 pairs (from index 4537)
# ✅ Appended 25 pairs. Current index: 4550
# ✅ Generated 25 pairs (from index 4550)
# ✅ Appended 25 pairs. Current index: 4563
# ✅ Generated 25 pairs (from index 4563)
# ✅ Appended 25 pairs. Current index: 4576
# ✅ Generated 25 pairs (from index 4576)
# ✅ Appended 25 pairs. Current index: 4589
# ✅ Generated 25 pairs (from index 4589)
# ✅ Appended 25 pairs. Current index: 4602
# ✅ Generated 25 pairs (from index 4602)
# ✅ Appended 25 pairs. Current index: 4615
# ✅ Generated 25 pairs (from index 4615)
# ✅ Appended 25 pairs. Current index: 4628
# ✅ Generated 25 pairs (from index 4628)
# ✅ Appended 25 pairs. Current index: 4641
# ✅ Generated 25 pairs (from index 4641)
# ✅ Appended 25 pairs. Current index: 4654
# ✅ Generated 25 pairs (from index 4654)
# ✅ Appended 25 pairs. Current index: 4667
# ✅ Generated 25 pairs (from index 4667)
# ✅ Appended 25 pairs. Current index: 4680
# ✅ Generated 25 pairs (from index 4680)
# ✅ Appended 25 pairs. Current index: 4693
# ✅ Generated 25 pairs (from index 4693)
# ✅ Appended 25 pairs. Current index: 4706
# ✅ Generated 25 pairs (from index 4706)
# ✅ Appended 25 pairs. Current index: 4719
# ✅ Generated 25 pairs (from index 4719)
# ✅ Appended 25 pairs. Current index: 4732
# ✅ Generated 25 pairs (from index 4732)
# ✅ Appended 25 pairs. Current index: 4745
# ✅ Generated 25 pairs (from index 4745)
# ✅ Appended 25 pairs. Current index: 4758
# ✅ Generated 25 pairs (from index 4758)
# ✅ Appended 25 pairs. Current index: 4771
# ✅ Generated 25 pairs (from index 4771)
# ✅ Appended 25 pairs. Current index: 4784
# ✅ Generated 25 pairs (from index 4784)
# ✅ Appended 25 pairs. Current index: 4797
# ✅ Generated 25 pairs (from index 4797)
# ✅ Appended 25 pairs. Current index: 4810
# ✅ Generated 25 pairs (from index 4810)
# ✅ Appended 25 pairs. Current index: 4823
# ✅ Generated 25 pairs (from index 4823)
# ✅ Appended 25 pairs. Current index: 4836
# ✅ Generated 25 pairs (from index 4836)
# ✅ Appended 25 pairs. Current index: 4849
# ✅ Generated 25 pairs (from index 4849)
# ✅ Appended 25 pairs. Current index: 4862
# ✅ Generated 25 pairs (from index 4862)
# ✅ Appended 25 pairs. Current index: 4875
# ✅ Generated 25 pairs (from index 4875)
# ✅ Appended 25 pairs. Current index: 4888
# ✅ Generated 25 pairs (from index 4888)
# ✅ Appended 25 pairs. Current index: 4901
# ✅ Generated 25 pairs (from index 4901)
# ✅ Appended 25 pairs. Current index: 4914
# ✅ Generated 25 pairs (from index 4914)
# ✅ Appended 25 pairs. Current index: 4927
# ✅ Generated 25 pairs (from index 4927)
# ✅ Appended 25 pairs. Current index: 4940
# ✅ Generated 25 pairs (from index 4940)
# ✅ Appended 25 pairs. Current index: 4953
# ✅ Generated 25 pairs (from index 4953)
# ✅ Appended 25 pairs. Current index: 4966
# ✅ Generated 25 pairs (from index 4966)
# ✅ Appended 25 pairs. Current index: 4979
# ✅ Generated 25 pairs (from index 4979)
# ✅ Appended 25 pairs. Current index: 4992
# ✅ Generated 25 pairs (from index 4992)
# ✅ Appended 25 pairs. Current index: 5005
# ✅ Generated 25 pairs (from index 5005)
# ✅ Appended 25 pairs. Current index: 5018
# ✅ Generated 25 pairs (from index 5018)
# ✅ Appended 25 pairs. Current index: 5031
# ✅ Generated 25 pairs (from index 5031)
# ✅ Appended 25 pairs. Current index: 5044
# ✅ Generated 25 pairs (from index 5044)
# ✅ Appended 25 pairs. Current index: 5057
# ✅ Generated 25 pairs (from index 5057)
# ✅ Appended 25 pairs. Current index: 5070
# ✅ Generated 25 pairs (from index 5070)
# ✅ Appended 25 pairs. Current index: 5083
# ✅ Generated 25 pairs (from index 5083)
# ✅ Appended 25 pairs. Current index: 5096
# ✅ Generated 25 pairs (from index 5096)
# ✅ Appended 25 pairs. Current index: 5109
# ✅ Generated 25 pairs (from index 5109)
# ✅ Appended 25 pairs. Current index: 5122
# ✅ Generated 25 pairs (from index 5122)
# ✅ Appended 25 pairs. Current index: 5135
# ✅ Generated 25 pairs (from index 5135)
# ✅ Appended 25 pairs. Current index: 5148
# ✅ Generated 25 pairs (from index 5148)
# ✅ Appended 25 pairs. Current index: 5161
# ✅ Generated 25 pairs (from index 5161)
# ✅ Appended 25 pairs. Current index: 5174
# ✅ Generated 25 pairs (from index 5174)
# ✅ Appended 25 pairs. Current index: 5187
# ✅ Generated 25 pairs (from index 5187)
# ✅ Appended 25 pairs. Current index: 5200
# ✅ Generated 25 pairs (from index 5200)
# ✅ Appended 25 pairs. Current index: 5213
# ✅ Generated 25 pairs (from index 5213)
# ✅ Appended 25 pairs. Current index: 5226
# ✅ Generated 25 pairs (from index 5226)
# ✅ Appended 25 pairs. Current index: 5239
# ✅ Generated 25 pairs (from index 5239)
# ✅ Appended 25 pairs. Current index: 5252
# ✅ Generated 25 pairs (from index 5252)
# ✅ Appended 25 pairs. Current index: 5265
# ✅ Generated 25 pairs (from index 5265)
# ✅ Appended 25 pairs. Current index: 5278
# ✅ Generated 25 pairs (from index 5278)
# ✅ Appended 25 pairs. Current index: 5291
# ✅ Generated 25 pairs (from index 5291)
# ✅ Appended 25 pairs. Current index: 5304
# ✅ Generated 25 pairs (from index 5304)
# ✅ Appended 25 pairs. Current index: 5317
# ✅ Generated 25 pairs (from index 5317)
# ✅ Appended 25 pairs. Current index: 5330
# ✅ Generated 25 pairs (from index 5330)
# ✅ Appended 25 pairs. Current index: 5343
# ✅ Generated 25 pairs (from index 5343)
# ✅ Appended 25 pairs. Current index: 5356
# ✅ Generated 25 pairs (from index 5356)
# ✅ Appended 25 pairs. Current index: 5369
# ✅ Generated 25 pairs (from index 5369)
# ✅ Appended 25 pairs. Current index: 5382
# ✅ Generated 25 pairs (from index 5382)
# ✅ Appended 25 pairs. Current index: 5395
# ✅ Generated 25 pairs (from index 5395)
# ✅ Appended 25 pairs. Current index: 5408
# ✅ Generated 25 pairs (from index 5408)
# ✅ Appended 25 pairs. Current index: 5421
# ✅ Generated 25 pairs (from index 5421)
# ✅ Appended 25 pairs. Current index: 5434
# ✅ Generated 25 pairs (from index 5434)
# ✅ Appended 25 pairs. Current index: 5447
# ✅ Generated 25 pairs (from index 5447)
# ✅ Appended 25 pairs. Current index: 5460
# ✅ Generated 25 pairs (from index 5460)
# ✅ Appended 25 pairs. Current index: 5473
# ✅ Generated 25 pairs (from index 5473)
# ✅ Appended 25 pairs. Current index: 5486
# ✅ Generated 25 pairs (from index 5486)
# ✅ Appended 25 pairs. Current index: 5499
# ✅ Generated 25 pairs (from index 5499)
# ✅ Appended 25 pairs. Current index: 5512
# ✅ Generated 25 pairs (from index 5512)
# ✅ Appended 25 pairs. Current index: 5525
# ✅ Generated 25 pairs (from index 5525)
# ✅ Appended 25 pairs. Current index: 5538
# ✅ Generated 25 pairs (from index 5538)
# ✅ Appended 25 pairs. Current index: 5551
# ✅ Generated 25 pairs (from index 5551)
# ✅ Appended 25 pairs. Current index: 5564
# ✅ Generated 25 pairs (from index 5564)
# ✅ Appended 25 pairs. Current index: 5577
# ✅ Generated 25 pairs (from index 5577)
# ✅ Appended 25 pairs. Current index: 5590
# ✅ Generated 25 pairs (from index 5590)
# ✅ Appended 25 pairs. Current index: 5603
# ✅ Generated 25 pairs (from index 5603)
# ✅ Appended 25 pairs. Current index: 5616
# ✅ Generated 25 pairs (from index 5616)
# ✅ Appended 25 pairs. Current index: 5629
# ✅ Generated 25 pairs (from index 5629)
# ✅ Appended 25 pairs. Current index: 5642
# ✅ Generated 25 pairs (from index 5642)
# ✅ Appended 25 pairs. Current index: 5655
# ✅ Generated 25 pairs (from index 5655)
# ✅ Appended 25 pairs. Current index: 5668
# ✅ Generated 25 pairs (from index 5668)
# ✅ Appended 25 pairs. Current index: 5681
# ✅ Generated 25 pairs (from index 5681)
# ✅ Appended 25 pairs. Current index: 5694
# ✅ Generated 25 pairs (from index 5694)
# ✅ Appended 25 pairs. Current index: 5707
# ✅ Generated 25 pairs (from index 5707)
# ✅ Appended 25 pairs. Current index: 5720
# ✅ Generated 25 pairs (from index 5720)
# ✅ Appended 25 pairs. Current index: 5733
# ✅ Generated 25 pairs (from index 5733)
# ✅ Appended 25 pairs. Current index: 5746
# ✅ Generated 25 pairs (from index 5746)
# ✅ Appended 25 pairs. Current index: 5759
# ✅ Generated 25 pairs (from index 5759)
# ✅ Appended 25 pairs. Current index: 5772
# ✅ Generated 25 pairs (from index 5772)
# ✅ Appended 25 pairs. Current index: 5785
# ✅ Generated 25 pairs (from index 5785)
# ✅ Appended 25 pairs. Current index: 5798
# ✅ Generated 25 pairs (from index 5798)
# ✅ Appended 25 pairs. Current index: 5811
# ✅ Generated 25 pairs (from index 5811)
# ✅ Appended 25 pairs. Current index: 5824
# ✅ Generated 25 pairs (from index 5824)
# ✅ Appended 25 pairs. Current index: 5837
# ✅ Generated 25 pairs (from index 5837)
# ✅ Appended 25 pairs. Current index: 5850
# ✅ Generated 25 pairs (from index 5850)
# ✅ Appended 25 pairs. Current index: 5863
# ✅ Generated 25 pairs (from index 5863)
# ✅ Appended 25 pairs. Current index: 5876
# ✅ Generated 25 pairs (from index 5876)
# ✅ Appended 25 pairs. Current index: 5889
# ✅ Generated 25 pairs (from index 5889)
# ✅ Appended 25 pairs. Current index: 5902
# ✅ Generated 25 pairs (from index 5902)
# ✅ Appended 25 pairs. Current index: 5915
# ✅ Generated 25 pairs (from index 5915)
# ✅ Appended 25 pairs. Current index: 5928
# ✅ Generated 25 pairs (from index 5928)
# ✅ Appended 25 pairs. Current index: 5941
# ✅ Generated 25 pairs (from index 5941)
# ✅ Appended 25 pairs. Current index: 5954
# ✅ Generated 25 pairs (from index 5954)
# ✅ Appended 25 pairs. Current index: 5967
# ✅ Generated 25 pairs (from index 5967)
# ✅ Appended 25 pairs. Current index: 5980
# ✅ Generated 25 pairs (from index 5980)
# ✅ Appended 25 pairs. Current index: 5993
# ✅ Generated 25 pairs (from index 5993)
# ✅ Appended 25 pairs. Current index: 6006
# ✅ Generated 25 pairs (from index 6006)
# ✅ Appended 25 pairs. Current index: 6019
# ✅ Generated 25 pairs (from index 6019)
# ✅ Appended 25 pairs. Current index: 6032
# ✅ Generated 25 pairs (from index 6032)
# ✅ Appended 25 pairs. Current index: 6045
# ✅ Generated 25 pairs (from index 6045)
# ✅ Appended 25 pairs. Current index: 6058
# ✅ Generated 25 pairs (from index 6058)
# ✅ Appended 25 pairs. Current index: 6071
# ✅ Generated 25 pairs (from index 6071)
# ✅ Appended 25 pairs. Current index: 6084
# ✅ Generated 25 pairs (from index 6084)
# ✅ Appended 25 pairs. Current index: 6097
# ✅ Generated 25 pairs (from index 6097)
# ✅ Appended 25 pairs. Current index: 6110
# ✅ Generated 25 pairs (from index 6110)
# ✅ Appended 25 pairs. Current index: 6123
# ✅ Generated 25 pairs (from index 6123)
# ✅ Appended 25 pairs. Current index: 6136
# ✅ Generated 25 pairs (from index 6136)
# ✅ Appended 25 pairs. Current index: 6149
# ✅ Generated 25 pairs (from index 6149)
# ✅ Appended 25 pairs. Current index: 6162
# ✅ Generated 25 pairs (from index 6162)
# ✅ Appended 25 pairs. Current index: 6175
# ✅ Generated 25 pairs (from index 6175)
# ✅ Appended 25 pairs. Current index: 6188
# ✅ Generated 25 pairs (from index 6188)
# ✅ Appended 25 pairs. Current index: 6201
# ✅ Generated 25 pairs (from index 6201)
# ✅ Appended 25 pairs. Current index: 6214
# ✅ Generated 25 pairs (from index 6214)
# ✅ Appended 25 pairs. Current index: 6227
# ✅ Generated 25 pairs (from index 6227)
# ✅ Appended 25 pairs. Current index: 6240
# ✅ Generated 25 pairs (from index 6240)
# ✅ Appended 25 pairs. Current index: 6253
# ✅ Generated 25 pairs (from index 6253)
# ✅ Appended 25 pairs. Current index: 6266
# ✅ Generated 25 pairs (from index 6266)
# ✅ Appended 25 pairs. Current index: 6279
# ✅ Generated 25 pairs (from index 6279)
# ✅ Appended 25 pairs. Current index: 6292
# ✅ Generated 25 pairs (from index 6292)
# ✅ Appended 25 pairs. Current index: 6305
# ✅ Generated 25 pairs (from index 6305)
# ✅ Appended 25 pairs. Current index: 6318
# ✅ Generated 25 pairs (from index 6318)
# ✅ Appended 25 pairs. Current index: 6331
# ✅ Generated 25 pairs (from index 6331)
# ✅ Appended 25 pairs. Current index: 6344
# ✅ Generated 25 pairs (from index 6344)
# ✅ Appended 25 pairs. Current index: 6357
# ✅ Generated 25 pairs (from index 6357)
# ✅ Appended 25 pairs. Current index: 6370
# ✅ Generated 25 pairs (from index 6370)
# ✅ Appended 25 pairs. Current index: 6383
# ✅ Generated 25 pairs (from index 6383)
# ✅ Appended 25 pairs. Current index: 6396
# ✅ Generated 25 pairs (from index 6396)
# ✅ Appended 25 pairs. Current index: 6409
# ✅ Generated 25 pairs (from index 6409)
# ✅ Appended 25 pairs. Current index: 6422
# ✅ Generated 25 pairs (from index 6422)
# ✅ Appended 25 pairs. Current index: 6435
# ✅ Generated 25 pairs (from index 6435)
# ✅ Appended 25 pairs. Current index: 6448
# ✅ Generated 25 pairs (from index 6448)
# ✅ Appended 25 pairs. Current index: 6461
# ✅ Generated 25 pairs (from index 6461)
# ✅ Appended 25 pairs. Current index: 6474
# ✅ Generated 25 pairs (from index 6474)
# ✅ Appended 25 pairs. Current index: 6487
# ✅ Generated 25 pairs (from index 6487)
# ✅ Appended 25 pairs. Current index: 6500
# ✅ Generated 25 pairs (from index 6500)
# ✅ Appended 25 pairs. Current index: 6513
# ✅ Generated 25 pairs (from index 6513)
# ✅ Appended 25 pairs. Current index: 6526
# ✅ Generated 25 pairs (from index 6526)
# ✅ Appended 25 pairs. Current index: 6539
# ✅ Generated 25 pairs (from index 6539)
# ✅ Appended 25 pairs. Current index: 6552
# ✅ Generated 25 pairs (from index 6552)
# ✅ Appended 25 pairs. Current index: 6565
# ✅ Generated 25 pairs (from index 6565)
# ✅ Appended 25 pairs. Current index: 6578
# ✅ Generated 25 pairs (from index 6578)
# ✅ Appended 25 pairs. Current index: 6591
# ✅ Generated 25 pairs (from index 6591)
# ✅ Appended 25 pairs. Current index: 6604
# ✅ Generated 25 pairs (from index 6604)
# ✅ Appended 25 pairs. Current index: 6617
# ✅ Generated 25 pairs (from index 6617)
# ✅ Appended 25 pairs. Current index: 6630
# ✅ Generated 25 pairs (from index 6630)
# ✅ Appended 25 pairs. Current index: 6643
# ✅ Generated 25 pairs (from index 6643)
# ✅ Appended 25 pairs. Current index: 6656
# ✅ Generated 25 pairs (from index 6656)
# ✅ Appended 25 pairs. Current index: 6669
# ✅ Generated 25 pairs (from index 6669)
# ✅ Appended 25 pairs. Current index: 6682
# ✅ Generated 25 pairs (from index 6682)
# ✅ Appended 25 pairs. Current index: 6695
# ✅ Generated 25 pairs (from index 6695)
# ✅ Appended 25 pairs. Current index: 6708
# ✅ Generated 25 pairs (from index 6708)
# ✅ Appended 25 pairs. Current index: 6721
# ✅ Generated 25 pairs (from index 6721)
# ✅ Appended 25 pairs. Current index: 6734
# ✅ Generated 25 pairs (from index 6734)
# ✅ Appended 25 pairs. Current index: 6747
# ✅ Generated 25 pairs (from index 6747)
# ✅ Appended 25 pairs. Current index: 6760
# ✅ Generated 25 pairs (from index 6760)
# ✅ Appended 25 pairs. Current index: 6773
# ✅ Generated 25 pairs (from index 6773)
# ✅ Appended 25 pairs. Current index: 6786
# ✅ Generated 25 pairs (from index 6786)
# ✅ Appended 25 pairs. Current index: 6799
# ✅ Generated 25 pairs (from index 6799)
# ✅ Appended 25 pairs. Current index: 6812
# ✅ Generated 25 pairs (from index 6812)
# ✅ Appended 25 pairs. Current index: 6825
# ✅ Generated 25 pairs (from index 6825)
# ✅ Appended 25 pairs. Current index: 6838
# ✅ Generated 25 pairs (from index 6838)
# ✅ Appended 25 pairs. Current index: 6851
# ✅ Generated 25 pairs (from index 6851)
# ✅ Appended 25 pairs. Current index: 6864
# ✅ Generated 25 pairs (from index 6864)
# ✅ Appended 25 pairs. Current index: 6877
# ✅ Generated 25 pairs (from index 6877)
# ✅ Appended 25 pairs. Current index: 6890
# ✅ Generated 25 pairs (from index 6890)
# ✅ Appended 25 pairs. Current index: 6903
# ✅ Generated 25 pairs (from index 6903)
# ✅ Appended 25 pairs. Current index: 6916
# ✅ Generated 25 pairs (from index 6916)
# ✅ Appended 25 pairs. Current index: 6929
# ✅ Generated 25 pairs (from index 6929)
# ✅ Appended 25 pairs. Current index: 6942
# ✅ Generated 25 pairs (from index 6942)
# ✅ Appended 25 pairs. Current index: 6955
# ✅ Generated 25 pairs (from index 6955)
# ✅ Appended 25 pairs. Current index: 6968
# ✅ Generated 25 pairs (from index 6968)
# ✅ Appended 25 pairs. Current index: 6981
# ✅ Generated 25 pairs (from index 6981)
# ✅ Appended 25 pairs. Current index: 6994
# ✅ Generated 25 pairs (from index 6994)
# ✅ Appended 25 pairs. Current index: 7007
# ✅ Generated 25 pairs (from index 7007)
# ✅ Appended 25 pairs. Current index: 7020
# ✅ Generated 25 pairs (from index 7020)
# ✅ Appended 25 pairs. Current index: 7033
# ✅ Generated 25 pairs (from index 7033)
# ✅ Appended 25 pairs. Current index: 7046
# ✅ Generated 25 pairs (from index 7046)
# ✅ Appended 25 pairs. Current index: 7059
# ✅ Generated 25 pairs (from index 7059)
# ✅ Appended 25 pairs. Current index: 7072
# ✅ Generated 25 pairs (from index 7072)
# ✅ Appended 25 pairs. Current index: 7085
# ✅ Generated 25 pairs (from index 7085)
# ✅ Appended 25 pairs. Current index: 7098
# ✅ Generated 25 pairs (from index 7098)
# ✅ Appended 25 pairs. Current index: 7111
# ✅ Generated 25 pairs (from index 7111)
# ✅ Appended 25 pairs. Current index: 7124
# ✅ Generated 25 pairs (from index 7124)
# ✅ Appended 25 pairs. Current index: 7137
# ✅ Generated 25 pairs (from index 7137)
# ✅ Appended 25 pairs. Current index: 7150
# ✅ Generated 25 pairs (from index 7150)
# ✅ Appended 25 pairs. Current index: 7163
# ✅ Generated 25 pairs (from index 7163)
# ✅ Appended 25 pairs. Current index: 7176
# ✅ Generated 25 pairs (from index 7176)
# ✅ Appended 25 pairs. Current index: 7189
# ✅ Generated 25 pairs (from index 7189)
# ✅ Appended 25 pairs. Current index: 7202
# ✅ Generated 25 pairs (from index 7202)
# ✅ Appended 25 pairs. Current index: 7215
# ✅ Generated 25 pairs (from index 7215)
# ✅ Appended 25 pairs. Current index: 7228
# ✅ Generated 25 pairs (from index 7228)
# ✅ Appended 25 pairs. Current index: 7241
# ✅ Generated 25 pairs (from index 7241)
# ✅ Appended 25 pairs. Current index: 7254
# ✅ Generated 25 pairs (from index 7254)
# ✅ Appended 25 pairs. Current index: 7267
# ✅ Generated 25 pairs (from index 7267)
# ✅ Appended 25 pairs. Current index: 7280
# ✅ Generated 25 pairs (from index 7280)
# ✅ Appended 25 pairs. Current index: 7293
# ✅ Generated 25 pairs (from index 7293)
# ✅ Appended 25 pairs. Current index: 7306
# ✅ Generated 25 pairs (from index 7306)
# ✅ Appended 25 pairs. Current index: 7319
# ✅ Generated 25 pairs (from index 7319)
# ✅ Appended 25 pairs. Current index: 7332
# ✅ Generated 25 pairs (from index 7332)
# ✅ Appended 25 pairs. Current index: 7345
# ✅ Generated 25 pairs (from index 7345)
# ✅ Appended 25 pairs. Current index: 7358
# ✅ Generated 25 pairs (from index 7358)
# ✅ Appended 25 pairs. Current index: 7371
# ✅ Generated 25 pairs (from index 7371)
# ✅ Appended 25 pairs. Current index: 7384
# ✅ Generated 25 pairs (from index 7384)
# ✅ Appended 25 pairs. Current index: 7397
# ✅ Generated 25 pairs (from index 7397)
# ✅ Appended 25 pairs. Current index: 7410
# ✅ Generated 25 pairs (from index 7410)
# ✅ Appended 25 pairs. Current index: 7423
# ✅ Generated 25 pairs (from index 7423)
# ✅ Appended 25 pairs. Current index: 7436
# ✅ Generated 25 pairs (from index 7436)
# ✅ Appended 25 pairs. Current index: 7449
# ✅ Generated 25 pairs (from index 7449)
# ✅ Appended 25 pairs. Current index: 7462
# ✅ Generated 25 pairs (from index 7462)
# ✅ Appended 25 pairs. Current index: 7475
# ✅ Generated 25 pairs (from index 7475)
# ✅ Appended 25 pairs. Current index: 7488
# ✅ Generated 25 pairs (from index 7488)
# ✅ Appended 25 pairs. Current index: 7501
# ✅ Generated 25 pairs (from index 7501)
# ✅ Appended 25 pairs. Current index: 7514
# ✅ Generated 25 pairs (from index 7514)
# ✅ Appended 25 pairs. Current index: 7527
# ✅ Generated 25 pairs (from index 7527)
# ✅ Appended 25 pairs. Current index: 7540
# ✅ Generated 25 pairs (from index 7540)
# ✅ Appended 25 pairs. Current index: 7553
# ✅ Generated 25 pairs (from index 7553)
# ✅ Appended 25 pairs. Current index: 7566
# ✅ Generated 25 pairs (from index 7566)
# ✅ Appended 25 pairs. Current index: 7579
# ✅ Generated 25 pairs (from index 7579)
# ✅ Appended 25 pairs. Current index: 7592
# ✅ Generated 25 pairs (from index 7592)
# ✅ Appended 25 pairs. Current index: 7605
# ✅ Generated 25 pairs (from index 7605)
# ✅ Appended 25 pairs. Current index: 7618
# ✅ Generated 25 pairs (from index 7618)
# ✅ Appended 25 pairs. Current index: 7631
# ✅ Generated 25 pairs (from index 7631)
# ✅ Appended 25 pairs. Current index: 7644
# ✅ Generated 25 pairs (from index 7644)
# ✅ Appended 25 pairs. Current index: 7657
# ✅ Generated 25 pairs (from index 7657)
# ✅ Appended 25 pairs. Current index: 7670
# ✅ Generated 25 pairs (from index 7670)
# ✅ Appended 25 pairs. Current index: 7683
# ✅ Generated 25 pairs (from index 7683)
# ✅ Appended 25 pairs. Current index: 7696
# ✅ Generated 25 pairs (from index 7696)
# ✅ Appended 25 pairs. Current index: 7709
# ✅ Generated 25 pairs (from index 7709)
# ✅ Appended 25 pairs. Current index: 7722
# ✅ Generated 25 pairs (from index 7722)
# ✅ Appended 25 pairs. Current index: 7735
# ✅ Generated 25 pairs (from index 7735)
# ✅ Appended 25 pairs. Current index: 7748
# ✅ Generated 25 pairs (from index 7748)
# ✅ Appended 25 pairs. Current index: 7761
# ✅ Generated 25 pairs (from index 7761)
# ✅ Appended 25 pairs. Current index: 7774
# ✅ Generated 25 pairs (from index 7774)
# ✅ Appended 25 pairs. Current index: 7787
# ✅ Generated 25 pairs (from index 7787)
# ✅ Appended 25 pairs. Current index: 7800
# ✅ Generated 25 pairs (from index 7800)
# ✅ Appended 25 pairs. Current index: 7813
# ✅ Generated 25 pairs (from index 7813)
# ✅ Appended 25 pairs. Current index: 7826
# ✅ Generated 25 pairs (from index 7826)
# ✅ Appended 25 pairs. Current index: 7839
# ✅ Generated 25 pairs (from index 7839)
# ✅ Appended 25 pairs. Current index: 7852
# ✅ Generated 25 pairs (from index 7852)
# ✅ Appended 25 pairs. Current index: 7865
# ✅ Generated 25 pairs (from index 7865)
# ✅ Appended 25 pairs. Current index: 7878
# ✅ Generated 25 pairs (from index 7878)
# ✅ Appended 25 pairs. Current index: 7891
# ✅ Generated 25 pairs (from index 7891)
# ✅ Appended 25 pairs. Current index: 7904
# ✅ Generated 25 pairs (from index 7904)
# ✅ Appended 25 pairs. Current index: 7917
# ✅ Generated 25 pairs (from index 7917)
# ✅ Appended 25 pairs. Current index: 7930
# ✅ Generated 25 pairs (from index 7930)
# ✅ Appended 25 pairs. Current index: 7943
# ✅ Generated 25 pairs (from index 7943)
# ✅ Appended 25 pairs. Current index: 7956
# ✅ Generated 25 pairs (from index 7956)
# ✅ Appended 25 pairs. Current index: 7969
# ✅ Generated 25 pairs (from index 7969)
# ✅ Appended 25 pairs. Current index: 7982
# ✅ Generated 25 pairs (from index 7982)
# ✅ Appended 25 pairs. Current index: 7995
# ✅ Generated 25 pairs (from index 7995)
# ✅ Appended 25 pairs. Current index: 8008
# ✅ Generated 25 pairs (from index 8008)
# ✅ Appended 25 pairs. Current index: 8021
# ✅ Generated 25 pairs (from index 8021)
# ✅ Appended 25 pairs. Current index: 8034
# ✅ Generated 25 pairs (from index 8034)
# ✅ Appended 25 pairs. Current index: 8047
# ✅ Completed entire pass from index 8047
# ✅ Appended 10 pairs. Current index: 8292

# %%
# --- Step 6: Save metadata file ---
pairs_df = pd.DataFrame(all_pairs)
pairs_df.to_csv(output_root / "pairs_metadata.csv", index=False)
print(f"✅ Saved {len(all_pairs)} metadata rows to:", output_root / "pairs_metadata.csv")
